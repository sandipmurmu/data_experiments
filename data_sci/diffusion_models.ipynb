# %%
#! pip install diffusers transformers accelerate

# %% [markdown]
# Here we use a StableDiffusion Pipeline. A Pipleline, is a framework which often provides single programming interface, abstracts the actual usage of models, whereby by several models (may vary in sizes) are leveraged and deployed to generate the output.

# %%
import torch

# checks the processor architecture, and returns the device
def get_device():
    device = None
    if torch.backends.mps.is_available():
        device = torch.device("mps")
    elif torch.cuda.is_available():
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    
    return device

# %%
from diffusers import StableDiffusion3Pipeline, DDPMScheduler
import torch

model_id = "CompVis/stable-diffusion-v1-4"
device = get_device()
pipe = StableDiffusion3Pipeline.from_pretrained(model_id)

pipe.to(device)
# Out:
# Fetching 16 files:  19%|█▉        | 3/16 [04:57<21:27, 99.06s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      49 with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                   initargs=(lk,)) as ex:
# ---> 51     return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     618 if timeout is None:
# --> 619     yield _result_or_cancel(fs.pop())
#     620 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     316 try:
# --> 317     return fut.result(timeout)
#     318 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     326 if timeout is None:
# --> 327     waiter.acquire()
#     328     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 model_id = "CompVis/stable-diffusion-v1-4"
#       5 device = get_device()
# ----> 6 pipe = StableDiffusion3Pipeline.from_pretrained(model_id)
#       8 pipe.to(device)
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/diffusers/pipelines/pipeline_utils.py:725, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     720     if pretrained_model_name_or_path.count("/") > 1:
#     721         raise ValueError(
#     722             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#     723             " is neither a valid local path nor a valid repo id. Please check the parameter."
#     724         )
# --> 725     cached_folder = cls.download(
#     726         pretrained_model_name_or_path,
#     727         cache_dir=cache_dir,
#     728         force_download=force_download,
#     729         proxies=proxies,
#     730         local_files_only=local_files_only,
#     731         token=token,
#     732         revision=revision,
#     733         from_flax=from_flax,
#     734         use_safetensors=use_safetensors,
#     735         use_onnx=use_onnx,
#     736         custom_pipeline=custom_pipeline,
#     737         custom_revision=custom_revision,
#     738         variant=variant,
#     739         load_connected_pipeline=load_connected_pipeline,
#     740         **kwargs,
#     741     )
#     742 else:
#     743     cached_folder = pretrained_model_name_or_path
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/diffusers/pipelines/pipeline_utils.py:1433, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1431 # download all allow_patterns - ignore_patterns
#    1432 try:
# -> 1433     cached_folder = snapshot_download(
#    1434         pretrained_model_name,
#    1435         cache_dir=cache_dir,
#    1436         proxies=proxies,
#    1437         local_files_only=local_files_only,
#    1438         token=token,
#    1439         revision=revision,
#    1440         allow_patterns=allow_patterns,
#    1441         ignore_patterns=ignore_patterns,
#    1442         user_agent=user_agent,
#    1443     )
#    1445     # retrieve pipeline class from local file
#    1446     cls_name = cls.load_config(os.path.join(cached_folder, "model_index.json")).get("_class_name", None)
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/huggingface_hub/_snapshot_download.py:293, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     291         _inner_hf_hub_download(file)
#     292 else:
# --> 293     thread_map(
#     294         _inner_hf_hub_download,
#     295         filtered_repo_files,
#     296         desc=f"Fetching {len(filtered_repo_files)} files",
#     297         max_workers=max_workers,
#     298         # User can use its own tqdm class or the default one from `huggingface_hub.utils`
#     299         tqdm_class=tqdm_class or hf_tqdm,
#     300     )
#     302 if local_dir is not None:
#     303     return str(os.path.realpath(local_dir))
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)
#      66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/projects/basic-examples/basic_venv/lib/python3.11/site-packages/tqdm/contrib/concurrent.py:49, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      46 lock_name = kwargs.pop("lock_name", "")
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
# ---> 49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
#      51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:
